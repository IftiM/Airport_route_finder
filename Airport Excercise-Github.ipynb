# %%
""" We have 3 data files to work with: airlines.dat, airports.dat and routes.dat
These files includes all known list of Airlines, Airports, and International Routes.
Our task is to get any two airport code: as source airport and destination airport.
Then we have to find if there's any direct flight between those two routes, if there's
any 2 legged routes between them, and if there's any 3 legged routes between them.

Part of Udacity Intermediate Python Nanodegree excercise

Name: Ifti Mustafa"""

import csv
import json


# Creating a custom dictionary from Airline code -> Airline Name (ie. ADE - Ada Air)
def read_airlines(filename='airlines.dat'):
    airlines = {}
    with open(filename) as f:
        reader = csv.reader(f)
        for line in reader:
            airlines[line[4]] = line[1]
    return airlines

# Creating a custom dictionary from Airport Code -> Airport Name (ie. DXB -Dubai Intl. Airport)
def read_airports(filename='airports.dat'):
    airport = {}
    with open(filename) as f:
        reader = csv.reader(f)
        for line in reader:
            airport[line[4]] = line[1]
    return airport

# Creating a custom dictionary with all the possible matching routes between all the airports in the database
def read_routes(filename='routes.dat'):
    routes = {}
    with open(filename) as f:
        reader = csv.reader(f)
        
        # Starting with source airport
        for line in reader:
            routes.setdefault(line[2], [])
            
            # Finding any possible destination matches, and append to a dictionary
            if line[4] in routes[line[2]]:
                pass
            else:
                routes[line[2]].append(line[4])
    return routes

_airlines = read_airlines()
# print(_airlines)
_airports = read_airports()
#print(_airports)
_routes = read_routes()
# print(_routes)


departure = 'CDG'
arrival = 'BOS'

if arrival in _routes.keys():
    if arrival in _routes[departure]: # Direct Flight
        print(f"Direct flight is possible between {_airports[departure]} and {_airports[arrival]}\n")
    else:
        print(f"Sorry!! Direct flight is NOT possible between {departure} and {_airports[arrival]}\n")

    for line in _routes[departure]: # 2 Legs
        if arrival in _routes[line]:
            print(f"Connecting flights possible between {departure}, {line}, {arrival}")

    for line in _routes[departure]: # 3 Legs
        for line2 in _routes[line]:
            if arrival in _routes[line2] and departure != line2 and arrival != line:
                print(f"Multi-Connecting flights possible between {departure}, {line}, {line2} {arrival}")
else:
    print(f"Sorry!! No flight is possible between {departure} and {_airports[arrival]}")
# Out:
# Direct flight is possible between Charles de Gaulle International Airport and General Edward Lawrence Logan International Airport
#
# Connecting flights possible between CDG, CLT, BOS
# Connecting flights possible between CDG, DFW, BOS
# Connecting flights possible between CDG, JFK, BOS
# Connecting flights possible between CDG, LHR, BOS
# Connecting flights possible between CDG, MIA, BOS
# Connecting flights possible between CDG, ORD, BOS
# Connecting flights possible between CDG, PHL, BOS
# Connecting flights possible between CDG, YUL, BOS
# Connecting flights possible between CDG, YYZ, BOS
# Connecting flights possible between CDG, AMS, BOS
# Connecting flights possible between CDG, ATL, BOS
# Connecting flights possible between CDG, CVG, BOS
# Connecting flights possible between CDG, DTW, BOS
# Connecting flights possible between CDG, DUB, BOS
# Connecting flights possible between CDG, DXB, BOS
# Connecting flights possible between CDG, EWR, BOS
# Connecting flights possible between CDG, FCO, BOS
# Connecting flights possible between CDG, FRA, BOS
# Connecting flights possible between CDG, IAD, BOS
# Connecting flights possible between CDG, IAH, BOS
# Connecting flights possible between CDG, LAX, BOS
# Connecting flights possible between CDG, LIS, BOS
# Connecting flights possible between CDG, MAD, BOS
# Connecting flights possible between CDG, MSP, BOS
# Connecting flights possible between CDG, MUC, BOS
# Connecting flights possible between CDG, NRT, BOS
# Connecting flights possible between CDG, PIT, BOS
# Connecting flights possible between CDG, PTY, BOS
# Connecting flights possible between CDG, PUJ, BOS
# Connecting flights possible between CDG, SEA, BOS
# Connecting flights possible between CDG, SFO, BOS
# Connecting flights possible between CDG, SLC, BOS
# Connecting flights possible between CDG, SXM, BOS
# Connecting flights possible between CDG, ZRH, BOS
# Connecting flights possible between CDG, KEF, BOS
# Connecting flights possible between CDG, CUN, BOS
# Connecting flights possible between CDG, RAI, BOS
# Multi-Connecting flights possible between CDG, HAM, AMS BOS
# Multi-Connecting flights possible between CDG, HAM, FCO BOS
# Multi-Connecting flights possible between CDG, HAM, LHR BOS
# Multi-Connecting flights possible between CDG, HAM, MAD BOS
# Multi-Connecting flights possible between CDG, HAM, ZRH BOS
# Multi-Connecting flights possible between CDG, HAM, MUC BOS
# Multi-Connecting flights possible between CDG, HAM, DUB BOS
# Multi-Connecting flights possible between CDG, HAM, DXB BOS
# Multi-Connecting flights possible between CDG, HAM, EWR BOS
# Multi-Connecting flights possible between CDG, HAM, FRA BOS
# Multi-Connecting flights possible between CDG, HAM, LIS BOS
# Multi-Connecting flights possible between CDG, IST, LHR BOS
# Multi-Connecting flights possible between CDG, IST, YYZ BOS
# Multi-Connecting flights possible between CDG, IST, FCO BOS
# Multi-Connecting flights possible between CDG, IST, DXB BOS
# Multi-Connecting flights possible between CDG, IST, AMS BOS
# Multi-Connecting flights possible between CDG, IST, FRA BOS
# Multi-Connecting flights possible between CDG, IST, MUC BOS
# Multi-Connecting flights possible between CDG, IST, ZRH BOS
# Multi-Connecting flights possible between CDG, IST, NRT BOS
# Multi-Connecting flights possible between CDG, IST, DUB BOS
# Multi-Connecting flights possible between CDG, IST, IAD BOS
# Multi-Connecting flights possible between CDG, IST, IAH BOS
# Multi-Connecting flights possible between CDG, IST, JFK BOS
# Multi-Connecting flights possible between CDG, IST, LAX BOS
# Multi-Connecting flights possible between CDG, IST, LIS BOS
# Multi-Connecting flights possible between CDG, IST, MAD BOS
# Multi-Connecting flights possible between CDG, IST, ORD BOS
# Multi-Connecting flights possible between CDG, ATH, FCO BOS
# Multi-Connecting flights possible between CDG, ATH, FRA BOS
# Multi-Connecting flights possible between CDG, ATH, LHR BOS
# Multi-Connecting flights possible between CDG, ATH, MAD BOS
# Multi-Connecting flights possible between CDG, ATH, MUC BOS
# Multi-Connecting flights possible between CDG, ATH, PHL BOS
# Multi-Connecting flights possible between CDG, ATH, DUB BOS
# Multi-Connecting flights possible between CDG, ATH, DXB BOS
# Multi-Connecting flights possible between CDG, ATH, AMS BOS
# Multi-Connecting flights possible between CDG, ATH, ZRH BOS
# Multi-Connecting flights possible between CDG, ATH, YUL BOS
# Multi-Connecting flights possible between CDG, ATH, YYZ BOS
# Multi-Connecting flights possible between CDG, HER, FRA BOS
# Multi-Connecting flights possible between CDG, HER, MUC BOS
# Multi-Connecting flights possible between CDG, HER, ZRH BOS
# Multi-Connecting flights possible between CDG, HER, AMS BOS
# Multi-Connecting flights possible between CDG, RHO, MUC BOS
# Multi-Connecting flights possible between CDG, RHO, FRA BOS
# Multi-Connecting flights possible between CDG, RHO, AMS BOS
# Multi-Connecting flights possible between CDG, SKG, FRA BOS
# Multi-Connecting flights possible between CDG, SKG, MUC BOS
# Multi-Connecting flights possible between CDG, SKG, FCO BOS
# Multi-Connecting flights possible between CDG, SKG, AMS BOS
# Multi-Connecting flights possible between CDG, TBS, AMS BOS
# Multi-Connecting flights possible between CDG, TBS, FCO BOS
# Multi-Connecting flights possible between CDG, TBS, DXB BOS
# Multi-Connecting flights possible between CDG, TBS, MUC BOS
# Multi-Connecting flights possible between CDG, CLT, ALB BOS
# Multi-Connecting flights possible between CDG, CLT, ATL BOS
# Multi-Connecting flights possible between CDG, CLT, AUA BOS
# Multi-Connecting flights possible between CDG, CLT, AUS BOS
# Multi-Connecting flights possible between CDG, CLT, BNA BOS
# Multi-Connecting flights possible between CDG, CLT, BUF BOS
# Multi-Connecting flights possible between CDG, CLT, BWI BOS
# Multi-Connecting flights possible between CDG, CLT, CAK BOS
# Multi-Connecting flights possible between CDG, CLT, CHS BOS
# Multi-Connecting flights possible between CDG, CLT, CLE BOS
# Multi-Connecting flights possible between CDG, CLT, CMH BOS
# Multi-Connecting flights possible between CDG, CLT, CUN BOS
# Multi-Connecting flights possible between CDG, CLT, CVG BOS
# Multi-Connecting flights possible between CDG, CLT, DCA BOS
# Multi-Connecting flights possible between CDG, CLT, DEN BOS
# Multi-Connecting flights possible between CDG, CLT, DFW BOS
# Multi-Connecting flights possible between CDG, CLT, DTW BOS
# Multi-Connecting flights possible between CDG, CLT, DUB BOS
# Multi-Connecting flights possible between CDG, CLT, EWR BOS
# Multi-Connecting flights possible between CDG, CLT, FCO BOS
# Multi-Connecting flights possible between CDG, CLT, FLL BOS
# Multi-Connecting flights possible between CDG, CLT, FRA BOS
# Multi-Connecting flights possible between CDG, CLT, IAD BOS
# Multi-Connecting flights possible between CDG, CLT, IAH BOS
# Multi-Connecting flights possible between CDG, CLT, IND BOS
# Multi-Connecting flights possible between CDG, CLT, JAX BOS
# Multi-Connecting flights possible between CDG, CLT, JFK BOS
# Multi-Connecting flights possible between CDG, CLT, LAS BOS
# Multi-Connecting flights possible between CDG, CLT, LAX BOS
# Multi-Connecting flights possible between CDG, CLT, LGA BOS
# Multi-Connecting flights possible between CDG, CLT, LHR BOS
# Multi-Connecting flights possible between CDG, CLT, MCI BOS
# Multi-Connecting flights possible between CDG, CLT, MCO BOS
# Multi-Connecting flights possible between CDG, CLT, MDT BOS
# Multi-Connecting flights possible between CDG, CLT, MIA BOS
# Multi-Connecting flights possible between CDG, CLT, MKE BOS
# Multi-Connecting flights possible between CDG, CLT, MSP BOS
# Multi-Connecting flights possible between CDG, CLT, MSY BOS
# Multi-Connecting flights possible between CDG, CLT, MYR BOS
# Multi-Connecting flights possible between CDG, CLT, NAS BOS
# Multi-Connecting flights possible between CDG, CLT, ORD BOS
# Multi-Connecting flights possible between CDG, CLT, PBI BOS
# Multi-Connecting flights possible between CDG, CLT, PDX BOS
# Multi-Connecting flights possible between CDG, CLT, PHL BOS
# Multi-Connecting flights possible between CDG, CLT, PHX BOS
# Multi-Connecting flights possible between CDG, CLT, PIT BOS
# Multi-Connecting flights possible between CDG, CLT, PLS BOS
# Multi-Connecting flights possible between CDG, CLT, PUJ BOS
# Multi-Connecting flights possible between CDG, CLT, RDU BOS
# Multi-Connecting flights possible between CDG, CLT, RIC BOS
# Multi-Connecting flights possible between CDG, CLT, ROC BOS
# Multi-Connecting flights possible between CDG, CLT, RSW BOS
# Multi-Connecting flights possible between CDG, CLT, SAN BOS
# Multi-Connecting flights possible between CDG, CLT, SAV BOS
# Multi-Connecting flights possible between CDG, CLT, SEA BOS
# Multi-Connecting flights possible between CDG, CLT, SFO BOS
# Multi-Connecting flights possible between CDG, CLT, SJU BOS
# Multi-Connecting flights possible between CDG, CLT, SLC BOS
# Multi-Connecting flights possible between CDG, CLT, STL BOS
# Multi-Connecting flights possible between CDG, CLT, SXM BOS
# Multi-Connecting flights possible between CDG, CLT, SYR BOS
# Multi-Connecting flights possible between CDG, CLT, TPA BOS
# Multi-Connecting flights possible between CDG, CLT, YOW BOS
# Multi-Connecting flights possible between CDG, CLT, YUL BOS
# Multi-Connecting flights possible between CDG, CLT, YYZ BOS
# Multi-Connecting flights possible between CDG, CLT, MDW BOS
# Multi-Connecting flights possible between CDG, CLT, MUC BOS
# Multi-Connecting flights possible between CDG, CLT, HOU BOS
# Multi-Connecting flights possible between CDG, DFW, ATL BOS
# Multi-Connecting flights possible between CDG, DFW, AUS BOS
# Multi-Connecting flights possible between CDG, DFW, BNA BOS
# Multi-Connecting flights possible between CDG, DFW, BWI BOS
# Multi-Connecting flights possible between CDG, DFW, CHS BOS
# Multi-Connecting flights possible between CDG, DFW, CLE BOS
# Multi-Connecting flights possible between CDG, DFW, CLT BOS
# Multi-Connecting flights possible between CDG, DFW, CMH BOS
# Multi-Connecting flights possible between CDG, DFW, CUN BOS
# Multi-Connecting flights possible between CDG, DFW, CVG BOS
# Multi-Connecting flights possible between CDG, DFW, DCA BOS
# Multi-Connecting flights possible between CDG, DFW, DEN BOS
# Multi-Connecting flights possible between CDG, DFW, DTW BOS
# Multi-Connecting flights possible between CDG, DFW, EWR BOS
# Multi-Connecting flights possible between CDG, DFW, FLL BOS
# Multi-Connecting flights possible between CDG, DFW, FRA BOS
# Multi-Connecting flights possible between CDG, DFW, HOU BOS
# Multi-Connecting flights possible between CDG, DFW, IAD BOS
# Multi-Connecting flights possible between CDG, DFW, IAH BOS
# Multi-Connecting flights possible between CDG, DFW, IND BOS
# Multi-Connecting flights possible between CDG, DFW, JAX BOS
# Multi-Connecting flights possible between CDG, DFW, JFK BOS
# Multi-Connecting flights possible between CDG, DFW, LAS BOS
# Multi-Connecting flights possible between CDG, DFW, LAX BOS
# Multi-Connecting flights possible between CDG, DFW, LGA BOS
# Multi-Connecting flights possible between CDG, DFW, LHR BOS
# Multi-Connecting flights possible between CDG, DFW, MAD BOS
# Multi-Connecting flights possible between CDG, DFW, MCI BOS
# Multi-Connecting flights possible between CDG, DFW, MCO BOS
# Multi-Connecting flights possible between CDG, DFW, MIA BOS
# Multi-Connecting flights possible between CDG, DFW, MKE BOS
# Multi-Connecting flights possible between CDG, DFW, MSP BOS
# Multi-Connecting flights possible between CDG, DFW, MSY BOS
# Multi-Connecting flights possible between CDG, DFW, NAS BOS
# Multi-Connecting flights possible between CDG, DFW, NRT BOS
# Multi-Connecting flights possible between CDG, DFW, ORD BOS
# Multi-Connecting flights possible between CDG, DFW, PBI BOS
# Multi-Connecting flights possible between CDG, DFW, PDX BOS
# Multi-Connecting flights possible between CDG, DFW, PHL BOS
# Multi-Connecting flights possible between CDG, DFW, PHX BOS
# Multi-Connecting flights possible between CDG, DFW, PIT BOS
# Multi-Connecting flights possible between CDG, DFW, PLS BOS
# Multi-Connecting flights possible between CDG, DFW, PTY BOS
# Multi-Connecting flights possible between CDG, DFW, RDU BOS
# Multi-Connecting flights possible between CDG, DFW, RIC BOS
# Multi-Connecting flights possible between CDG, DFW, RSW BOS
# Multi-Connecting flights possible between CDG, DFW, SAN BOS
# Multi-Connecting flights possible between CDG, DFW, SAV BOS
# Multi-Connecting flights possible between CDG, DFW, SEA BOS
# Multi-Connecting flights possible between CDG, DFW, SFO BOS
# Multi-Connecting flights possible between CDG, DFW, SJC BOS
# Multi-Connecting flights possible between CDG, DFW, SJU BOS
# Multi-Connecting flights possible between CDG, DFW, SLC BOS
# Multi-Connecting flights possible between CDG, DFW, STL BOS
# Multi-Connecting flights possible between CDG, DFW, TPA BOS
# Multi-Connecting flights possible between CDG, DFW, YUL BOS
# Multi-Connecting flights possible between CDG, DFW, YYZ BOS
# Multi-Connecting flights possible between CDG, DFW, DXB BOS
# Multi-Connecting flights possible between CDG, DFW, AMS BOS
# Multi-Connecting flights possible between CDG, DFW, MYR BOS
# Multi-Connecting flights possible between CDG, JFK, MSY BOS
# Multi-Connecting flights possible between CDG, JFK, AUS BOS
# Multi-Connecting flights possible between CDG, JFK, BDA BOS
# Multi-Connecting flights possible between CDG, JFK, BNA BOS
# Multi-Connecting flights possible between CDG, JFK, BWI BOS
# Multi-Connecting flights possible between CDG, JFK, CLE BOS
# Multi-Connecting flights possible between CDG, JFK, CLT BOS
# Multi-Connecting flights possible between CDG, JFK, CMH BOS
# Multi-Connecting flights possible between CDG, JFK, CUN BOS
# Multi-Connecting flights possible between CDG, JFK, CVG BOS
# Multi-Connecting flights possible between CDG, JFK, DCA BOS
# Multi-Connecting flights possible between CDG, JFK, DFW BOS
# Multi-Connecting flights possible between CDG, JFK, DUB BOS
# Multi-Connecting flights possible between CDG, JFK, FCO BOS
# Multi-Connecting flights possible between CDG, JFK, IND BOS
# Multi-Connecting flights possible between CDG, JFK, LAS BOS
# Multi-Connecting flights possible between CDG, JFK, LAX BOS
# Multi-Connecting flights possible between CDG, JFK, LHR BOS
# Multi-Connecting flights possible between CDG, JFK, MAD BOS
# Multi-Connecting flights possible between CDG, JFK, MCO BOS
# Multi-Connecting flights possible between CDG, JFK, MIA BOS
# Multi-Connecting flights possible between CDG, JFK, NRT BOS
# Multi-Connecting flights possible between CDG, JFK, ORD BOS
# Multi-Connecting flights possible between CDG, JFK, PHX BOS
# Multi-Connecting flights possible between CDG, JFK, PIT BOS
# Multi-Connecting flights possible between CDG, JFK, RDU BOS
# Multi-Connecting flights possible between CDG, JFK, SAN BOS
# Multi-Connecting flights possible between CDG, JFK, SEA BOS
# Multi-Connecting flights possible between CDG, JFK, SFO BOS
# Multi-Connecting flights possible between CDG, JFK, SJU BOS
# Multi-Connecting flights possible between CDG, JFK, SXM BOS
# Multi-Connecting flights possible between CDG, JFK, TPA BOS
# Multi-Connecting flights possible between CDG, JFK, YUL BOS
# Multi-Connecting flights possible between CDG, JFK, YYZ BOS
# Multi-Connecting flights possible between CDG, JFK, ZRH BOS
# Multi-Connecting flights possible between CDG, JFK, ATL BOS
# Multi-Connecting flights possible between CDG, JFK, FRA BOS
# Multi-Connecting flights possible between CDG, JFK, AUA BOS
# Multi-Connecting flights possible between CDG, JFK, BUF BOS
# Multi-Connecting flights possible between CDG, JFK, CHS BOS
# Multi-Connecting flights possible between CDG, JFK, DEN BOS
# Multi-Connecting flights possible between CDG, JFK, DXB BOS
# Multi-Connecting flights possible between CDG, JFK, FLL BOS
# Multi-Connecting flights possible between CDG, JFK, HOU BOS
# Multi-Connecting flights possible between CDG, JFK, IAD BOS
# Multi-Connecting flights possible between CDG, JFK, JAX BOS
# Multi-Connecting flights possible between CDG, JFK, LGB BOS
# Multi-Connecting flights possible between CDG, JFK, NAS BOS
# Multi-Connecting flights possible between CDG, JFK, PBI BOS
# Multi-Connecting flights possible between CDG, JFK, PDX BOS
# Multi-Connecting flights possible between CDG, JFK, PLS BOS
# Multi-Connecting flights possible between CDG, JFK, PUJ BOS
# Multi-Connecting flights possible between CDG, JFK, ROC BOS
# Multi-Connecting flights possible between CDG, JFK, RSW BOS
# Multi-Connecting flights possible between CDG, JFK, SAV BOS
# Multi-Connecting flights possible between CDG, JFK, SDQ BOS
# Multi-Connecting flights possible between CDG, JFK, SJC BOS
# Multi-Connecting flights possible between CDG, JFK, SLC BOS
# Multi-Connecting flights possible between CDG, JFK, STI BOS
# Multi-Connecting flights possible between CDG, JFK, SYR BOS
# Multi-Connecting flights possible between CDG, JFK, PTY BOS
# Multi-Connecting flights possible between CDG, JFK, AMS BOS
# Multi-Connecting flights possible between CDG, JFK, DTW BOS
# Multi-Connecting flights possible between CDG, JFK, MSP BOS
# Multi-Connecting flights possible between CDG, JFK, PHL BOS
# Multi-Connecting flights possible between CDG, JFK, RIC BOS
# Multi-Connecting flights possible between CDG, JFK, STL BOS
# Multi-Connecting flights possible between CDG, JFK, SNN BOS
# Multi-Connecting flights possible between CDG, JFK, KEF BOS
# Multi-Connecting flights possible between CDG, JFK, MUC BOS
# Multi-Connecting flights possible between CDG, KUL, FRA BOS
# Multi-Connecting flights possible between CDG, KUL, LHR BOS
# Multi-Connecting flights possible between CDG, KUL, NRT BOS
# Multi-Connecting flights possible between CDG, KUL, AMS BOS
# Multi-Connecting flights possible between CDG, KUL, DXB BOS
# Multi-Connecting flights possible between CDG, LHR, AMS BOS
# Multi-Connecting flights possible between CDG, LHR, ATL BOS
# Multi-Connecting flights possible between CDG, LHR, AUS BOS
# Multi-Connecting flights possible between CDG, LHR, BWI BOS
# Multi-Connecting flights possible between CDG, LHR, CLT BOS
# Multi-Connecting flights possible between CDG, LHR, DEN BOS
# Multi-Connecting flights possible between CDG, LHR, DFW BOS
# Multi-Connecting flights possible between CDG, LHR, DUB BOS
# Multi-Connecting flights possible between CDG, LHR, DXB BOS
# Multi-Connecting flights possible between CDG, LHR, EWR BOS
# Multi-Connecting flights possible between CDG, LHR, FCO BOS
# Multi-Connecting flights possible between CDG, LHR, FRA BOS
# Multi-Connecting flights possible between CDG, LHR, IAD BOS
# Multi-Connecting flights possible between CDG, LHR, IAH BOS
# Multi-Connecting flights possible between CDG, LHR, JFK BOS
# Multi-Connecting flights possible between CDG, LHR, LAS BOS
# Multi-Connecting flights possible between CDG, LHR, LAX BOS
# Multi-Connecting flights possible between CDG, LHR, LIS BOS
# Multi-Connecting flights possible between CDG, LHR, MIA BOS
# Multi-Connecting flights possible between CDG, LHR, MUC BOS
# Multi-Connecting flights possible between CDG, LHR, ORD BOS
# Multi-Connecting flights possible between CDG, LHR, PHL BOS
# Multi-Connecting flights possible between CDG, LHR, PHX BOS
# Multi-Connecting flights possible between CDG, LHR, RDU BOS
# Multi-Connecting flights possible between CDG, LHR, SAN BOS
# Multi-Connecting flights possible between CDG, LHR, SEA BOS
# Multi-Connecting flights possible between CDG, LHR, SFO BOS
# Multi-Connecting flights possible between CDG, LHR, YUL BOS
# Multi-Connecting flights possible between CDG, LHR, YYZ BOS
# Multi-Connecting flights possible between CDG, LHR, ZRH BOS
# Multi-Connecting flights possible between CDG, LHR, YHZ BOS
# Multi-Connecting flights possible between CDG, LHR, YOW BOS
# Multi-Connecting flights possible between CDG, LHR, DTW BOS
# Multi-Connecting flights possible between CDG, LHR, MSP BOS
# Multi-Connecting flights possible between CDG, LHR, MAD BOS
# Multi-Connecting flights possible between CDG, LHR, NAS BOS
# Multi-Connecting flights possible between CDG, LHR, NRT BOS
# Multi-Connecting flights possible between CDG, LHR, SNN BOS
# Multi-Connecting flights possible between CDG, LHR, KEF BOS
# Multi-Connecting flights possible between CDG, MIA, PUJ BOS
# Multi-Connecting flights possible between CDG, MIA, AUA BOS
# Multi-Connecting flights possible between CDG, MIA, ATL BOS
# Multi-Connecting flights possible between CDG, MIA, BDA BOS
# Multi-Connecting flights possible between CDG, MIA, BNA BOS
# Multi-Connecting flights possible between CDG, MIA, BWI BOS
# Multi-Connecting flights possible between CDG, MIA, CHS BOS
# Multi-Connecting flights possible between CDG, MIA, CLE BOS
# Multi-Connecting flights possible between CDG, MIA, CLT BOS
# Multi-Connecting flights possible between CDG, MIA, CMH BOS
# Multi-Connecting flights possible between CDG, MIA, CUN BOS
# Multi-Connecting flights possible between CDG, MIA, CVG BOS
# Multi-Connecting flights possible between CDG, MIA, DCA BOS
# Multi-Connecting flights possible between CDG, MIA, DEN BOS
# Multi-Connecting flights possible between CDG, MIA, DFW BOS
# Multi-Connecting flights possible between CDG, MIA, DTW BOS
# Multi-Connecting flights possible between CDG, MIA, EWR BOS
# Multi-Connecting flights possible between CDG, MIA, IAD BOS
# Multi-Connecting flights possible between CDG, MIA, IAH BOS
# Multi-Connecting flights possible between CDG, MIA, IND BOS
# Multi-Connecting flights possible between CDG, MIA, JAX BOS
# Multi-Connecting flights possible between CDG, MIA, JFK BOS
# Multi-Connecting flights possible between CDG, MIA, LAS BOS
# Multi-Connecting flights possible between CDG, MIA, LAX BOS
# Multi-Connecting flights possible between CDG, MIA, LGA BOS
# Multi-Connecting flights possible between CDG, MIA, LHR BOS
# Multi-Connecting flights possible between CDG, MIA, MAD BOS
# Multi-Connecting flights possible between CDG, MIA, MCO BOS
# Multi-Connecting flights possible between CDG, MIA, MSP BOS
# Multi-Connecting flights possible between CDG, MIA, MSY BOS
# Multi-Connecting flights possible between CDG, MIA, NAS BOS
# Multi-Connecting flights possible between CDG, MIA, ORD BOS
# Multi-Connecting flights possible between CDG, MIA, PHL BOS
# Multi-Connecting flights possible between CDG, MIA, PHX BOS
# Multi-Connecting flights possible between CDG, MIA, PIT BOS
# Multi-Connecting flights possible between CDG, MIA, PLS BOS
# Multi-Connecting flights possible between CDG, MIA, PTY BOS
# Multi-Connecting flights possible between CDG, MIA, RDU BOS
# Multi-Connecting flights possible between CDG, MIA, RIC BOS
# Multi-Connecting flights possible between CDG, MIA, SAN BOS
# Multi-Connecting flights possible between CDG, MIA, SDQ BOS
# Multi-Connecting flights possible between CDG, MIA, SEA BOS
# Multi-Connecting flights possible between CDG, MIA, SFO BOS
# Multi-Connecting flights possible between CDG, MIA, SJU BOS
# Multi-Connecting flights possible between CDG, MIA, STI BOS
# Multi-Connecting flights possible between CDG, MIA, STL BOS
# Multi-Connecting flights possible between CDG, MIA, SXM BOS
# Multi-Connecting flights possible between CDG, MIA, TPA BOS
# Multi-Connecting flights possible between CDG, MIA, YUL BOS
# Multi-Connecting flights possible between CDG, MIA, YYZ BOS
# Multi-Connecting flights possible between CDG, MIA, FCO BOS
# Multi-Connecting flights possible between CDG, MIA, FRA BOS
# Multi-Connecting flights possible between CDG, MIA, ZRH BOS
# Multi-Connecting flights possible between CDG, MIA, AMS BOS
# Multi-Connecting flights possible between CDG, MIA, LIS BOS
# Multi-Connecting flights possible between CDG, ORD, ATL BOS
# Multi-Connecting flights possible between CDG, ORD, AUS BOS
# Multi-Connecting flights possible between CDG, ORD, BNA BOS
# Multi-Connecting flights possible between CDG, ORD, BUF BOS
# Multi-Connecting flights possible between CDG, ORD, BWI BOS
# Multi-Connecting flights possible between CDG, ORD, CLE BOS
# Multi-Connecting flights possible between CDG, ORD, CLT BOS
# Multi-Connecting flights possible between CDG, ORD, CMH BOS
# Multi-Connecting flights possible between CDG, ORD, CUN BOS
# Multi-Connecting flights possible between CDG, ORD, CVG BOS
# Multi-Connecting flights possible between CDG, ORD, DCA BOS
# Multi-Connecting flights possible between CDG, ORD, DEN BOS
# Multi-Connecting flights possible between CDG, ORD, DFW BOS
# Multi-Connecting flights possible between CDG, ORD, DTW BOS
# Multi-Connecting flights possible between CDG, ORD, DUB BOS
# Multi-Connecting flights possible between CDG, ORD, EWR BOS
# Multi-Connecting flights possible between CDG, ORD, FCO BOS
# Multi-Connecting flights possible between CDG, ORD, FLL BOS
# Multi-Connecting flights possible between CDG, ORD, IAH BOS
# Multi-Connecting flights possible between CDG, ORD, IND BOS
# Multi-Connecting flights possible between CDG, ORD, JAX BOS
# Multi-Connecting flights possible between CDG, ORD, JFK BOS
# Multi-Connecting flights possible between CDG, ORD, LAS BOS
# Multi-Connecting flights possible between CDG, ORD, LAX BOS
# Multi-Connecting flights possible between CDG, ORD, LGA BOS
# Multi-Connecting flights possible between CDG, ORD, LHR BOS
# Multi-Connecting flights possible between CDG, ORD, MAD BOS
# Multi-Connecting flights possible between CDG, ORD, MCI BOS
# Multi-Connecting flights possible between CDG, ORD, MCO BOS
# Multi-Connecting flights possible between CDG, ORD, MDT BOS
# Multi-Connecting flights possible between CDG, ORD, MIA BOS
# Multi-Connecting flights possible between CDG, ORD, MKE BOS
# Multi-Connecting flights possible between CDG, ORD, MSP BOS
# Multi-Connecting flights possible between CDG, ORD, MSY BOS
# Multi-Connecting flights possible between CDG, ORD, NRT BOS
# Multi-Connecting flights possible between CDG, ORD, PBI BOS
# Multi-Connecting flights possible between CDG, ORD, PDX BOS
# Multi-Connecting flights possible between CDG, ORD, PHL BOS
# Multi-Connecting flights possible between CDG, ORD, PHX BOS
# Multi-Connecting flights possible between CDG, ORD, PIT BOS
# Multi-Connecting flights possible between CDG, ORD, RDU BOS
# Multi-Connecting flights possible between CDG, ORD, RIC BOS
# Multi-Connecting flights possible between CDG, ORD, ROC BOS
# Multi-Connecting flights possible between CDG, ORD, RSW BOS
# Multi-Connecting flights possible between CDG, ORD, SAN BOS
# Multi-Connecting flights possible between CDG, ORD, SEA BOS
# Multi-Connecting flights possible between CDG, ORD, SFO BOS
# Multi-Connecting flights possible between CDG, ORD, SJC BOS
# Multi-Connecting flights possible between CDG, ORD, SJU BOS
# Multi-Connecting flights possible between CDG, ORD, SLC BOS
# Multi-Connecting flights possible between CDG, ORD, STL BOS
# Multi-Connecting flights possible between CDG, ORD, SYR BOS
# Multi-Connecting flights possible between CDG, ORD, TPA BOS
# Multi-Connecting flights possible between CDG, ORD, YUL BOS
# Multi-Connecting flights possible between CDG, ORD, YYZ BOS
# Multi-Connecting flights possible between CDG, ORD, YHZ BOS
# Multi-Connecting flights possible between CDG, ORD, YOW BOS
# Multi-Connecting flights possible between CDG, ORD, PTY BOS
# Multi-Connecting flights possible between CDG, ORD, AMS BOS
# Multi-Connecting flights possible between CDG, ORD, PUJ BOS
# Multi-Connecting flights possible between CDG, ORD, FRA BOS
# Multi-Connecting flights possible between CDG, ORD, MUC BOS
# Multi-Connecting flights possible between CDG, ORD, ZRH BOS
# Multi-Connecting flights possible between CDG, ORD, ACY BOS
# Multi-Connecting flights possible between CDG, ORD, MYR BOS
# Multi-Connecting flights possible between CDG, ORD, ALB BOS
# Multi-Connecting flights possible between CDG, ORD, CAK BOS
# Multi-Connecting flights possible between CDG, ORD, CHS BOS
# Multi-Connecting flights possible between CDG, ORD, IAD BOS
# Multi-Connecting flights possible between CDG, ORD, NAS BOS
# Multi-Connecting flights possible between CDG, ORD, SAV BOS
# Multi-Connecting flights possible between CDG, ORD, SXM BOS
# Multi-Connecting flights possible between CDG, PHL, ALB BOS
# Multi-Connecting flights possible between CDG, PHL, AMS BOS
# Multi-Connecting flights possible between CDG, PHL, ATL BOS
# Multi-Connecting flights possible between CDG, PHL, AUA BOS
# Multi-Connecting flights possible between CDG, PHL, AUS BOS
# Multi-Connecting flights possible between CDG, PHL, BDA BOS
# Multi-Connecting flights possible between CDG, PHL, BNA BOS
# Multi-Connecting flights possible between CDG, PHL, BUF BOS
# Multi-Connecting flights possible between CDG, PHL, BWI BOS
# Multi-Connecting flights possible between CDG, PHL, CAK BOS
# Multi-Connecting flights possible between CDG, PHL, CHS BOS
# Multi-Connecting flights possible between CDG, PHL, CLE BOS
# Multi-Connecting flights possible between CDG, PHL, CLT BOS
# Multi-Connecting flights possible between CDG, PHL, CMH BOS
# Multi-Connecting flights possible between CDG, PHL, CUN BOS
# Multi-Connecting flights possible between CDG, PHL, CVG BOS
# Multi-Connecting flights possible between CDG, PHL, DCA BOS
# Multi-Connecting flights possible between CDG, PHL, DEN BOS
# Multi-Connecting flights possible between CDG, PHL, DFW BOS
# Multi-Connecting flights possible between CDG, PHL, DTW BOS
# Multi-Connecting flights possible between CDG, PHL, DUB BOS
# Multi-Connecting flights possible between CDG, PHL, EWR BOS
# Multi-Connecting flights possible between CDG, PHL, FCO BOS
# Multi-Connecting flights possible between CDG, PHL, FLL BOS
# Multi-Connecting flights possible between CDG, PHL, FRA BOS
# Multi-Connecting flights possible between CDG, PHL, IAH BOS
# Multi-Connecting flights possible between CDG, PHL, IND BOS
# Multi-Connecting flights possible between CDG, PHL, ISP BOS
# Multi-Connecting flights possible between CDG, PHL, JAX BOS
# Multi-Connecting flights possible between CDG, PHL, LAS BOS
# Multi-Connecting flights possible between CDG, PHL, LAX BOS
# Multi-Connecting flights possible between CDG, PHL, LGA BOS
# Multi-Connecting flights possible between CDG, PHL, LHR BOS
# Multi-Connecting flights possible between CDG, PHL, LIS BOS
# Multi-Connecting flights possible between CDG, PHL, MAD BOS
# Multi-Connecting flights possible between CDG, PHL, MCI BOS
# Multi-Connecting flights possible between CDG, PHL, MCO BOS
# Multi-Connecting flights possible between CDG, PHL, MDT BOS
# Multi-Connecting flights possible between CDG, PHL, MIA BOS
# Multi-Connecting flights possible between CDG, PHL, MKE BOS
# Multi-Connecting flights possible between CDG, PHL, MSP BOS
# Multi-Connecting flights possible between CDG, PHL, MSY BOS
# Multi-Connecting flights possible between CDG, PHL, MUC BOS
# Multi-Connecting flights possible between CDG, PHL, MYR BOS
# Multi-Connecting flights possible between CDG, PHL, NAS BOS
# Multi-Connecting flights possible between CDG, PHL, ORD BOS
# Multi-Connecting flights possible between CDG, PHL, PBI BOS
# Multi-Connecting flights possible between CDG, PHL, PDX BOS
# Multi-Connecting flights possible between CDG, PHL, PHX BOS
# Multi-Connecting flights possible between CDG, PHL, PIT BOS
# Multi-Connecting flights possible between CDG, PHL, PLS BOS
# Multi-Connecting flights possible between CDG, PHL, PUJ BOS
# Multi-Connecting flights possible between CDG, PHL, RDU BOS
# Multi-Connecting flights possible between CDG, PHL, RIC BOS
# Multi-Connecting flights possible between CDG, PHL, ROC BOS
# Multi-Connecting flights possible between CDG, PHL, RSW BOS
# Multi-Connecting flights possible between CDG, PHL, SAN BOS
# Multi-Connecting flights possible between CDG, PHL, SAV BOS
# Multi-Connecting flights possible between CDG, PHL, SDQ BOS
# Multi-Connecting flights possible between CDG, PHL, SEA BOS
# Multi-Connecting flights possible between CDG, PHL, SFO BOS
# Multi-Connecting flights possible between CDG, PHL, SJU BOS
# Multi-Connecting flights possible between CDG, PHL, SLC BOS
# Multi-Connecting flights possible between CDG, PHL, STL BOS
# Multi-Connecting flights possible between CDG, PHL, SXM BOS
# Multi-Connecting flights possible between CDG, PHL, SYR BOS
# Multi-Connecting flights possible between CDG, PHL, TPA BOS
# Multi-Connecting flights possible between CDG, PHL, YHZ BOS
# Multi-Connecting flights possible between CDG, PHL, YOW BOS
# Multi-Connecting flights possible between CDG, PHL, YUL BOS
# Multi-Connecting flights possible between CDG, PHL, YYZ BOS
# Multi-Connecting flights possible between CDG, PHL, ZRH BOS
# Multi-Connecting flights possible between CDG, PHL, JFK BOS
# Multi-Connecting flights possible between CDG, PHL, MDW BOS
# Multi-Connecting flights possible between CDG, PHL, IAD BOS
# Multi-Connecting flights possible between CDG, VIE, LHR BOS
# Multi-Connecting flights possible between CDG, VIE, FCO BOS
# Multi-Connecting flights possible between CDG, VIE, FRA BOS
# Multi-Connecting flights possible between CDG, VIE, MAD BOS
# Multi-Connecting flights possible between CDG, VIE, MUC BOS
# Multi-Connecting flights possible between CDG, VIE, ZRH BOS
# Multi-Connecting flights possible between CDG, VIE, YYZ BOS
# Multi-Connecting flights possible between CDG, VIE, DUB BOS
# Multi-Connecting flights possible between CDG, VIE, DXB BOS
# Multi-Connecting flights possible between CDG, VIE, AMS BOS
# Multi-Connecting flights possible between CDG, VIE, NRT BOS
# Multi-Connecting flights possible between CDG, VIE, IAD BOS
# Multi-Connecting flights possible between CDG, VIE, JFK BOS
# Multi-Connecting flights possible between CDG, VIE, LIS BOS
# Multi-Connecting flights possible between CDG, VIE, ORD BOS
# Multi-Connecting flights possible between CDG, YUL, CLT BOS
# Multi-Connecting flights possible between CDG, YUL, DCA BOS
# Multi-Connecting flights possible between CDG, YUL, DFW BOS
# Multi-Connecting flights possible between CDG, YUL, DTW BOS
# Multi-Connecting flights possible between CDG, YUL, JFK BOS
# Multi-Connecting flights possible between CDG, YUL, LGA BOS
# Multi-Connecting flights possible between CDG, YUL, LHR BOS
# Multi-Connecting flights possible between CDG, YUL, MIA BOS
# Multi-Connecting flights possible between CDG, YUL, ORD BOS
# Multi-Connecting flights possible between CDG, YUL, PHL BOS
# Multi-Connecting flights possible between CDG, YUL, CUN BOS
# Multi-Connecting flights possible between CDG, YUL, DEN BOS
# Multi-Connecting flights possible between CDG, YUL, EWR BOS
# Multi-Connecting flights possible between CDG, YUL, FLL BOS
# Multi-Connecting flights possible between CDG, YUL, FRA BOS
# Multi-Connecting flights possible between CDG, YUL, IAD BOS
# Multi-Connecting flights possible between CDG, YUL, IAH BOS
# Multi-Connecting flights possible between CDG, YUL, LAS BOS
# Multi-Connecting flights possible between CDG, YUL, LAX BOS
# Multi-Connecting flights possible between CDG, YUL, MCO BOS
# Multi-Connecting flights possible between CDG, YUL, MUC BOS
# Multi-Connecting flights possible between CDG, YUL, PUJ BOS
# Multi-Connecting flights possible between CDG, YUL, SFO BOS
# Multi-Connecting flights possible between CDG, YUL, YHZ BOS
# Multi-Connecting flights possible between CDG, YUL, YOW BOS
# Multi-Connecting flights possible between CDG, YUL, YTZ BOS
# Multi-Connecting flights possible between CDG, YUL, YYZ BOS
# Multi-Connecting flights possible between CDG, YUL, ZRH BOS
# Multi-Connecting flights possible between CDG, YUL, ATL BOS
# Multi-Connecting flights possible between CDG, YUL, AMS BOS
# Multi-Connecting flights possible between CDG, YUL, MSP BOS
# Multi-Connecting flights possible between CDG, YUL, FCO BOS
# Multi-Connecting flights possible between CDG, YUL, LIS BOS
# Multi-Connecting flights possible between CDG, YYZ, CLT BOS
# Multi-Connecting flights possible between CDG, YYZ, DCA BOS
# Multi-Connecting flights possible between CDG, YYZ, DFW BOS
# Multi-Connecting flights possible between CDG, YYZ, JFK BOS
# Multi-Connecting flights possible between CDG, YYZ, LAS BOS
# Multi-Connecting flights possible between CDG, YYZ, LAX BOS
# Multi-Connecting flights possible between CDG, YYZ, LGA BOS
# Multi-Connecting flights possible between CDG, YYZ, LHR BOS
# Multi-Connecting flights possible between CDG, YYZ, MCO BOS
# Multi-Connecting flights possible between CDG, YYZ, MIA BOS
# Multi-Connecting flights possible between CDG, YYZ, ORD BOS
# Multi-Connecting flights possible between CDG, YYZ, PHL BOS
# Multi-Connecting flights possible between CDG, YYZ, ATL BOS
# Multi-Connecting flights possible between CDG, YYZ, AUA BOS
# Multi-Connecting flights possible between CDG, YYZ, BDA BOS
# Multi-Connecting flights possible between CDG, YYZ, BNA BOS
# Multi-Connecting flights possible between CDG, YYZ, BWI BOS
# Multi-Connecting flights possible between CDG, YYZ, CLE BOS
# Multi-Connecting flights possible between CDG, YYZ, CMH BOS
# Multi-Connecting flights possible between CDG, YYZ, CUN BOS
# Multi-Connecting flights possible between CDG, YYZ, CVG BOS
# Multi-Connecting flights possible between CDG, YYZ, DEN BOS
# Multi-Connecting flights possible between CDG, YYZ, DTW BOS
# Multi-Connecting flights possible between CDG, YYZ, DUB BOS
# Multi-Connecting flights possible between CDG, YYZ, EWR BOS
# Multi-Connecting flights possible between CDG, YYZ, FCO BOS
# Multi-Connecting flights possible between CDG, YYZ, FLL BOS
# Multi-Connecting flights possible between CDG, YYZ, FRA BOS
# Multi-Connecting flights possible between CDG, YYZ, IAD BOS
# Multi-Connecting flights possible between CDG, YYZ, IAH BOS
# Multi-Connecting flights possible between CDG, YYZ, IND BOS
# Multi-Connecting flights possible between CDG, YYZ, MCI BOS
# Multi-Connecting flights possible between CDG, YYZ, MDT BOS
# Multi-Connecting flights possible between CDG, YYZ, MKE BOS
# Multi-Connecting flights possible between CDG, YYZ, MSP BOS
# Multi-Connecting flights possible between CDG, YYZ, MSY BOS
# Multi-Connecting flights possible between CDG, YYZ, MUC BOS
# Multi-Connecting flights possible between CDG, YYZ, NAS BOS
# Multi-Connecting flights possible between CDG, YYZ, NRT BOS
# Multi-Connecting flights possible between CDG, YYZ, PHX BOS
# Multi-Connecting flights possible between CDG, YYZ, PIT BOS
# Multi-Connecting flights possible between CDG, YYZ, PLS BOS
# Multi-Connecting flights possible between CDG, YYZ, PUJ BOS
# Multi-Connecting flights possible between CDG, YYZ, RDU BOS
# Multi-Connecting flights possible between CDG, YYZ, ROC BOS
# Multi-Connecting flights possible between CDG, YYZ, RSW BOS
# Multi-Connecting flights possible between CDG, YYZ, SAN BOS
# Multi-Connecting flights possible between CDG, YYZ, SEA BOS
# Multi-Connecting flights possible between CDG, YYZ, SFO BOS
# Multi-Connecting flights possible between CDG, YYZ, STL BOS
# Multi-Connecting flights possible between CDG, YYZ, SYR BOS
# Multi-Connecting flights possible between CDG, YYZ, TPA BOS
# Multi-Connecting flights possible between CDG, YYZ, YHZ BOS
# Multi-Connecting flights possible between CDG, YYZ, YOW BOS
# Multi-Connecting flights possible between CDG, YYZ, YUL BOS
# Multi-Connecting flights possible between CDG, YYZ, ZRH BOS
# Multi-Connecting flights possible between CDG, YYZ, PTY BOS
# Multi-Connecting flights possible between CDG, YYZ, AMS BOS
# Multi-Connecting flights possible between CDG, YYZ, DXB BOS
# Multi-Connecting flights possible between CDG, YYZ, KEF BOS
# Multi-Connecting flights possible between CDG, YYZ, LIS BOS
# Multi-Connecting flights possible between CDG, YYZ, PDL BOS
# Multi-Connecting flights possible between CDG, YYZ, MYR BOS
# Multi-Connecting flights possible between CDG, YYZ, SJU BOS
# Multi-Connecting flights possible between CDG, YYZ, SXM BOS
# Multi-Connecting flights possible between CDG, ABV, LHR BOS
# Multi-Connecting flights possible between CDG, ABV, FRA BOS
# Multi-Connecting flights possible between CDG, ABZ, LHR BOS
# Multi-Connecting flights possible between CDG, ABZ, DUB BOS
# Multi-Connecting flights possible between CDG, ABZ, AMS BOS
# Multi-Connecting flights possible between CDG, ABZ, FRA BOS
# Multi-Connecting flights possible between CDG, AGP, LHR BOS
# Multi-Connecting flights possible between CDG, AGP, MUC BOS
# Multi-Connecting flights possible between CDG, AGP, FCO BOS
# Multi-Connecting flights possible between CDG, AGP, DUB BOS
# Multi-Connecting flights possible between CDG, AGP, SNN BOS
# Multi-Connecting flights possible between CDG, AGP, AMS BOS
# Multi-Connecting flights possible between CDG, AGP, MAD BOS
# Multi-Connecting flights possible between CDG, AGP, FRA BOS
# Multi-Connecting flights possible between CDG, AGP, ZRH BOS
# Multi-Connecting flights possible between CDG, AGP, LIS BOS
# Multi-Connecting flights possible between CDG, AGP, YUL BOS
# Multi-Connecting flights possible between CDG, ALG, DXB BOS
# Multi-Connecting flights possible between CDG, ALG, FCO BOS
# Multi-Connecting flights possible between CDG, ALG, FRA BOS
# Multi-Connecting flights possible between CDG, ALG, LHR BOS
# Multi-Connecting flights possible between CDG, ALG, LIS BOS
# Multi-Connecting flights possible between CDG, ALG, MAD BOS
# Multi-Connecting flights possible between CDG, ALG, YUL BOS
# Multi-Connecting flights possible between CDG, AMM, JFK BOS
# Multi-Connecting flights possible between CDG, AMM, ORD BOS
# Multi-Connecting flights possible between CDG, AMM, YUL BOS
# Multi-Connecting flights possible between CDG, AMM, FRA BOS
# Multi-Connecting flights possible between CDG, AMM, MUC BOS
# Multi-Connecting flights possible between CDG, AMM, FCO BOS
# Multi-Connecting flights possible between CDG, AMM, LHR BOS
# Multi-Connecting flights possible between CDG, AMM, DXB BOS
# Multi-Connecting flights possible between CDG, AMM, MAD BOS
# Multi-Connecting flights possible between CDG, AMM, AMS BOS
# Multi-Connecting flights possible between CDG, AMM, ZRH BOS
# Multi-Connecting flights possible between CDG, AMS, LHR BOS
# Multi-Connecting flights possible between CDG, AMS, PHL BOS
# Multi-Connecting flights possible between CDG, AMS, LIS BOS
# Multi-Connecting flights possible between CDG, AMS, DXB BOS
# Multi-Connecting flights possible between CDG, AMS, FCO BOS
# Multi-Connecting flights possible between CDG, AMS, PTY BOS
# Multi-Connecting flights possible between CDG, AMS, ATL BOS
# Multi-Connecting flights possible between CDG, AMS, DFW BOS
# Multi-Connecting flights possible between CDG, AMS, DTW BOS
# Multi-Connecting flights possible between CDG, AMS, EWR BOS
# Multi-Connecting flights possible between CDG, AMS, IAD BOS
# Multi-Connecting flights possible between CDG, AMS, IAH BOS
# Multi-Connecting flights possible between CDG, AMS, JFK BOS
# Multi-Connecting flights possible between CDG, AMS, LAX BOS
# Multi-Connecting flights possible between CDG, AMS, MSP BOS
# Multi-Connecting flights possible between CDG, AMS, ORD BOS
# Multi-Connecting flights possible between CDG, AMS, PDX BOS
# Multi-Connecting flights possible between CDG, AMS, SEA BOS
# Multi-Connecting flights possible between CDG, AMS, SFO BOS
# Multi-Connecting flights possible between CDG, AMS, YUL BOS
# Multi-Connecting flights possible between CDG, AMS, YYZ BOS
# Multi-Connecting flights possible between CDG, AMS, DUB BOS
# Multi-Connecting flights possible between CDG, AMS, FRA BOS
# Multi-Connecting flights possible between CDG, AMS, KEF BOS
# Multi-Connecting flights possible between CDG, AMS, AUA BOS
# Multi-Connecting flights possible between CDG, AMS, MAD BOS
# Multi-Connecting flights possible between CDG, AMS, MUC BOS
# Multi-Connecting flights possible between CDG, AMS, NRT BOS
# Multi-Connecting flights possible between CDG, AMS, SXM BOS
# Multi-Connecting flights possible between CDG, AMS, ZRH BOS
# Multi-Connecting flights possible between CDG, AMS, PUJ BOS
# Multi-Connecting flights possible between CDG, AMS, PDL BOS
# Multi-Connecting flights possible between CDG, ARN, LHR BOS
# Multi-Connecting flights possible between CDG, ARN, AMS BOS
# Multi-Connecting flights possible between CDG, ARN, FCO BOS
# Multi-Connecting flights possible between CDG, ARN, FLL BOS
# Multi-Connecting flights possible between CDG, ARN, JFK BOS
# Multi-Connecting flights possible between CDG, ARN, LAX BOS
# Multi-Connecting flights possible between CDG, ARN, MUC BOS
# Multi-Connecting flights possible between CDG, ARN, DUB BOS
# Multi-Connecting flights possible between CDG, ARN, DXB BOS
# Multi-Connecting flights possible between CDG, ARN, FRA BOS
# Multi-Connecting flights possible between CDG, ARN, KEF BOS
# Multi-Connecting flights possible between CDG, ARN, MAD BOS
# Multi-Connecting flights possible between CDG, ARN, ZRH BOS
# Multi-Connecting flights possible between CDG, ARN, LIS BOS
# Multi-Connecting flights possible between CDG, ARN, EWR BOS
# Multi-Connecting flights possible between CDG, ARN, ORD BOS
# Multi-Connecting flights possible between CDG, ATL, CVG BOS
# Multi-Connecting flights possible between CDG, ATL, MSP BOS
# Multi-Connecting flights possible between CDG, ATL, SYR BOS
# Multi-Connecting flights possible between CDG, ATL, CLT BOS
# Multi-Connecting flights possible between CDG, ATL, DFW BOS
# Multi-Connecting flights possible between CDG, ATL, LHR BOS
# Multi-Connecting flights possible between CDG, ATL, MIA BOS
# Multi-Connecting flights possible between CDG, ATL, ORD BOS
# Multi-Connecting flights possible between CDG, ATL, PHL BOS
# Multi-Connecting flights possible between CDG, ATL, PHX BOS
# Multi-Connecting flights possible between CDG, ATL, DEN BOS
# Multi-Connecting flights possible between CDG, ATL, YYZ BOS
# Multi-Connecting flights possible between CDG, ATL, ALB BOS
# Multi-Connecting flights possible between CDG, ATL, AUS BOS
# Multi-Connecting flights possible between CDG, ATL, BNA BOS
# Multi-Connecting flights possible between CDG, ATL, BUF BOS
# Multi-Connecting flights possible between CDG, ATL, BWI BOS
# Multi-Connecting flights possible between CDG, ATL, CAK BOS
# Multi-Connecting flights possible between CDG, ATL, CHS BOS
# Multi-Connecting flights possible between CDG, ATL, CLE BOS
# Multi-Connecting flights possible between CDG, ATL, CMH BOS
# Multi-Connecting flights possible between CDG, ATL, CUN BOS
# Multi-Connecting flights possible between CDG, ATL, DCA BOS
# Multi-Connecting flights possible between CDG, ATL, DTW BOS
# Multi-Connecting flights possible between CDG, ATL, DUB BOS
# Multi-Connecting flights possible between CDG, ATL, EWR BOS
# Multi-Connecting flights possible between CDG, ATL, FCO BOS
# Multi-Connecting flights possible between CDG, ATL, FLL BOS
# Multi-Connecting flights possible between CDG, ATL, FRA BOS
# Multi-Connecting flights possible between CDG, ATL, IAD BOS
# Multi-Connecting flights possible between CDG, ATL, IAH BOS
# Multi-Connecting flights possible between CDG, ATL, IND BOS
# Multi-Connecting flights possible between CDG, ATL, JAX BOS
# Multi-Connecting flights possible between CDG, ATL, JFK BOS
# Multi-Connecting flights possible between CDG, ATL, LAS BOS
# Multi-Connecting flights possible between CDG, ATL, LAX BOS
# Multi-Connecting flights possible between CDG, ATL, LGA BOS
# Multi-Connecting flights possible between CDG, ATL, MAD BOS
# Multi-Connecting flights possible between CDG, ATL, MCI BOS
# Multi-Connecting flights possible between CDG, ATL, MCO BOS
# Multi-Connecting flights possible between CDG, ATL, MDT BOS
# Multi-Connecting flights possible between CDG, ATL, MDW BOS
# Multi-Connecting flights possible between CDG, ATL, MKE BOS
# Multi-Connecting flights possible between CDG, ATL, MSY BOS
# Multi-Connecting flights possible between CDG, ATL, MUC BOS
# Multi-Connecting flights possible between CDG, ATL, MYR BOS
# Multi-Connecting flights possible between CDG, ATL, NAS BOS
# Multi-Connecting flights possible between CDG, ATL, PBI BOS
# Multi-Connecting flights possible between CDG, ATL, PDX BOS
# Multi-Connecting flights possible between CDG, ATL, PIT BOS
# Multi-Connecting flights possible between CDG, ATL, PTY BOS
# Multi-Connecting flights possible between CDG, ATL, RDU BOS
# Multi-Connecting flights possible between CDG, ATL, RIC BOS
# Multi-Connecting flights possible between CDG, ATL, ROC BOS
# Multi-Connecting flights possible between CDG, ATL, RSW BOS
# Multi-Connecting flights possible between CDG, ATL, SAN BOS
# Multi-Connecting flights possible between CDG, ATL, SAV BOS
# Multi-Connecting flights possible between CDG, ATL, SEA BOS
# Multi-Connecting flights possible between CDG, ATL, SFO BOS
# Multi-Connecting flights possible between CDG, ATL, SJU BOS
# Multi-Connecting flights possible between CDG, ATL, SLC BOS
# Multi-Connecting flights possible between CDG, ATL, STL BOS
# Multi-Connecting flights possible between CDG, ATL, TPA BOS
# Multi-Connecting flights possible between CDG, ATL, YUL BOS
# Multi-Connecting flights possible between CDG, ATL, HOU BOS
# Multi-Connecting flights possible between CDG, ATL, AMS BOS
# Multi-Connecting flights possible between CDG, ATL, AUA BOS
# Multi-Connecting flights possible between CDG, ATL, BDA BOS
# Multi-Connecting flights possible between CDG, ATL, DXB BOS
# Multi-Connecting flights possible between CDG, ATL, NRT BOS
# Multi-Connecting flights possible between CDG, ATL, PLS BOS
# ...
# Multi-Connecting flights possible between CDG, LBA, DUB BOS
# Multi-Connecting flights possible between CDG, LBA, FCO BOS
# Multi-Connecting flights possible between CDG, VNO, FRA BOS
# Multi-Connecting flights possible between CDG, VNO, DUB BOS
# Multi-Connecting flights possible between CDG, VNO, MUC BOS
# Multi-Connecting flights possible between CDG, VNO, FCO BOS
# Multi-Connecting flights possible between CDG, LXR, LHR BOS
# Multi-Connecting flights possible between CDG, DBV, DUB BOS
# Multi-Connecting flights possible between CDG, DBV, FRA BOS
# Multi-Connecting flights possible between CDG, DBV, MUC BOS
# Multi-Connecting flights possible between CDG, DBV, ZRH BOS
# Multi-Connecting flights possible between CDG, DBV, AMS BOS
# Multi-Connecting flights possible between CDG, DBV, FCO BOS
# Multi-Connecting flights possible between CDG, SPU, FRA BOS
# Multi-Connecting flights possible between CDG, SPU, MUC BOS
# Multi-Connecting flights possible between CDG, SPU, ZRH BOS
# Multi-Connecting flights possible between CDG, SPU, FCO BOS
# Multi-Connecting flights possible between CDG, SPU, LHR BOS
# Multi-Connecting flights possible between CDG, ISB, DXB BOS
# Multi-Connecting flights possible between CDG, ISB, LHR BOS
# Multi-Connecting flights possible between CDG, ISB, YYZ BOS
# Multi-Connecting flights possible between CDG, LHE, DXB BOS
# Multi-Connecting flights possible between CDG, LHE, LHR BOS
# Multi-Connecting flights possible between CDG, LHE, YYZ BOS
# Multi-Connecting flights possible between CDG, MXP, JFK BOS
# Multi-Connecting flights possible between CDG, MXP, LHR BOS
# Multi-Connecting flights possible between CDG, MXP, MIA BOS
# Multi-Connecting flights possible between CDG, MXP, FCO BOS
# Multi-Connecting flights possible between CDG, MXP, LIS BOS
# Multi-Connecting flights possible between CDG, MXP, NRT BOS
# Multi-Connecting flights possible between CDG, MXP, DXB BOS
# Multi-Connecting flights possible between CDG, MXP, CUN BOS
# Multi-Connecting flights possible between CDG, MXP, DUB BOS
# Multi-Connecting flights possible between CDG, MXP, FRA BOS
# Multi-Connecting flights possible between CDG, MXP, MAD BOS
# Multi-Connecting flights possible between CDG, MXP, EWR BOS
# Multi-Connecting flights possible between CDG, MXP, MUC BOS
# Multi-Connecting flights possible between CDG, MXP, ZRH BOS
# Multi-Connecting flights possible between CDG, MXP, AMS BOS
# Multi-Connecting flights possible between CDG, DOH, IAD BOS
# Multi-Connecting flights possible between CDG, DOH, IAH BOS
# Multi-Connecting flights possible between CDG, DOH, JFK BOS
# Multi-Connecting flights possible between CDG, DOH, ORD BOS
# Multi-Connecting flights possible between CDG, DOH, PHL BOS
# Multi-Connecting flights possible between CDG, DOH, FRA BOS
# Multi-Connecting flights possible between CDG, DOH, AMS BOS
# Multi-Connecting flights possible between CDG, DOH, DXB BOS
# Multi-Connecting flights possible between CDG, DOH, MAD BOS
# Multi-Connecting flights possible between CDG, DOH, NRT BOS
# Multi-Connecting flights possible between CDG, DOH, FCO BOS
# Multi-Connecting flights possible between CDG, DOH, LHR BOS
# Multi-Connecting flights possible between CDG, DOH, MUC BOS
# Multi-Connecting flights possible between CDG, DOH, YUL BOS
# Multi-Connecting flights possible between CDG, DOH, ZRH BOS
# Multi-Connecting flights possible between CDG, BVC, LIS BOS
# Multi-Connecting flights possible between CDG, BVC, RAI BOS
# Multi-Connecting flights possible between CDG, CUN, CLT BOS
# Multi-Connecting flights possible between CDG, CUN, DFW BOS
# Multi-Connecting flights possible between CDG, CUN, JFK BOS
# Multi-Connecting flights possible between CDG, CUN, MIA BOS
# Multi-Connecting flights possible between CDG, CUN, ORD BOS
# Multi-Connecting flights possible between CDG, CUN, PHL BOS
# Multi-Connecting flights possible between CDG, CUN, PHX BOS
# Multi-Connecting flights possible between CDG, CUN, YUL BOS
# Multi-Connecting flights possible between CDG, CUN, YYZ BOS
# Multi-Connecting flights possible between CDG, CUN, ATL BOS
# Multi-Connecting flights possible between CDG, CUN, DTW BOS
# Multi-Connecting flights possible between CDG, CUN, IND BOS
# Multi-Connecting flights possible between CDG, CUN, LAX BOS
# Multi-Connecting flights possible between CDG, CUN, MAD BOS
# Multi-Connecting flights possible between CDG, CUN, MCO BOS
# Multi-Connecting flights possible between CDG, CUN, MSP BOS
# Multi-Connecting flights possible between CDG, CUN, PTY BOS
# Multi-Connecting flights possible between CDG, CUN, RDU BOS
# Multi-Connecting flights possible between CDG, CUN, SLC BOS
# Multi-Connecting flights possible between CDG, CUN, FLL BOS
# Multi-Connecting flights possible between CDG, CUN, FCO BOS
# Multi-Connecting flights possible between CDG, CUN, IAH BOS
# Multi-Connecting flights possible between CDG, CUN, FRA BOS
# Multi-Connecting flights possible between CDG, CUN, CVG BOS
# Multi-Connecting flights possible between CDG, CUN, CLE BOS
# Multi-Connecting flights possible between CDG, CUN, DEN BOS
# Multi-Connecting flights possible between CDG, CUN, MCI BOS
# Multi-Connecting flights possible between CDG, CUN, PIT BOS
# Multi-Connecting flights possible between CDG, CUN, STL BOS
# Multi-Connecting flights possible between CDG, CUN, AUS BOS
# Multi-Connecting flights possible between CDG, CUN, BWI BOS
# Multi-Connecting flights possible between CDG, CUN, MDW BOS
# Multi-Connecting flights possible between CDG, CUN, MKE BOS
# Multi-Connecting flights possible between CDG, CUN, AMS BOS
# Multi-Connecting flights possible between CDG, CUN, YHZ BOS
# Multi-Connecting flights possible between CDG, CUN, EWR BOS
# Multi-Connecting flights possible between CDG, CUN, IAD BOS
# Multi-Connecting flights possible between CDG, CUN, SFO BOS
# Multi-Connecting flights possible between CDG, FDF, SDQ BOS
# Multi-Connecting flights possible between CDG, FDF, MIA BOS
# Multi-Connecting flights possible between CDG, FDF, SJU BOS
# Multi-Connecting flights possible between CDG, FDF, YUL BOS
# Multi-Connecting flights possible between CDG, LPA, ZRH BOS
# Multi-Connecting flights possible between CDG, LPA, MAD BOS
# Multi-Connecting flights possible between CDG, LPA, MUC BOS
# Multi-Connecting flights possible between CDG, LPA, FRA BOS
# Multi-Connecting flights possible between CDG, LPA, DUB BOS
# Multi-Connecting flights possible between CDG, LPA, AMS BOS
# Multi-Connecting flights possible between CDG, LPA, LIS BOS
# Multi-Connecting flights possible between CDG, LPA, RAI BOS
# Multi-Connecting flights possible between CDG, POP, MIA BOS
# Multi-Connecting flights possible between CDG, POP, YHZ BOS
# Multi-Connecting flights possible between CDG, POP, YYZ BOS
# Multi-Connecting flights possible between CDG, POP, JFK BOS
# Multi-Connecting flights possible between CDG, POP, FRA BOS
# Multi-Connecting flights possible between CDG, POP, PLS BOS
# Multi-Connecting flights possible between CDG, POP, SJU BOS
# Multi-Connecting flights possible between CDG, POP, PUJ BOS
# Multi-Connecting flights possible between CDG, POP, EWR BOS
# Multi-Connecting flights possible between CDG, PTP, SDQ BOS
# Multi-Connecting flights possible between CDG, PTP, SXM BOS
# Multi-Connecting flights possible between CDG, PTP, MIA BOS
# Multi-Connecting flights possible between CDG, PTP, SJU BOS
# Multi-Connecting flights possible between CDG, PTP, YUL BOS
# Multi-Connecting flights possible between CDG, SID, AMS BOS
# Multi-Connecting flights possible between CDG, SID, LIS BOS
# Multi-Connecting flights possible between CDG, SID, RAI BOS
# Multi-Connecting flights possible between CDG, SID, FRA BOS
# Multi-Connecting flights possible between CDG, SID, MUC BOS
# Multi-Connecting flights possible between CDG, JER, FRA BOS
# Multi-Connecting flights possible between CDG, JER, DUB BOS
# Multi-Connecting flights possible between CDG, JER, AMS BOS
# Multi-Connecting flights possible between CDG, JER, ZRH BOS
# Multi-Connecting flights possible between CDG, SAW, MUC BOS
# Multi-Connecting flights possible between CDG, SAW, DXB BOS
# Multi-Connecting flights possible between CDG, SAW, AMS BOS
# Multi-Connecting flights possible between CDG, SAW, FCO BOS
# Multi-Connecting flights possible between CDG, SAW, FRA BOS
# Multi-Connecting flights possible between CDG, SAW, MAD BOS
# Multi-Connecting flights possible between CDG, SAW, ZRH BOS
# Multi-Connecting flights possible between CDG, YQB, YUL BOS
# Multi-Connecting flights possible between CDG, YQB, PHL BOS
# Multi-Connecting flights possible between CDG, YQB, ORD BOS
# Multi-Connecting flights possible between CDG, YQB, YOW BOS
# Multi-Connecting flights possible between CDG, YQB, YYZ BOS
# Multi-Connecting flights possible between CDG, YQB, YTZ BOS
# Multi-Connecting flights possible between CDG, YQB, PUJ BOS
# Multi-Connecting flights possible between CDG, YQB, EWR BOS
# Multi-Connecting flights possible between CDG, AGA, FRA BOS
# Multi-Connecting flights possible between CDG, AGA, MUC BOS
# Multi-Connecting flights possible between CDG, AGA, AMS BOS
# Multi-Connecting flights possible between CDG, BFS, EWR BOS
# Multi-Connecting flights possible between CDG, BFS, AMS BOS
# Multi-Connecting flights possible between CDG, BIA, FRA BOS
# Multi-Connecting flights possible between CDG, BIQ, DUB BOS
# Multi-Connecting flights possible between CDG, BRI, FCO BOS
# Multi-Connecting flights possible between CDG, BRI, MUC BOS
# Multi-Connecting flights possible between CDG, BRI, DUB BOS
# Multi-Connecting flights possible between CDG, BRI, AMS BOS
# Multi-Connecting flights possible between CDG, BRS, ZRH BOS
# Multi-Connecting flights possible between CDG, BRS, AMS BOS
# Multi-Connecting flights possible between CDG, BRS, FRA BOS
# Multi-Connecting flights possible between CDG, BRS, MUC BOS
# Multi-Connecting flights possible between CDG, BRS, DUB BOS
# Multi-Connecting flights possible between CDG, BRS, SNN BOS
# Multi-Connecting flights possible between CDG, BRS, FCO BOS
# Multi-Connecting flights possible between CDG, BRS, KEF BOS
# Multi-Connecting flights possible between CDG, BRS, LIS BOS
# Multi-Connecting flights possible between CDG, BRS, MAD BOS
# Multi-Connecting flights possible between CDG, GLA, LHR BOS
# Multi-Connecting flights possible between CDG, GLA, PHL BOS
# Multi-Connecting flights possible between CDG, GLA, AMS BOS
# Multi-Connecting flights possible between CDG, GLA, CUN BOS
# Multi-Connecting flights possible between CDG, GLA, MCO BOS
# Multi-Connecting flights possible between CDG, GLA, DUB BOS
# Multi-Connecting flights possible between CDG, GLA, DXB BOS
# Multi-Connecting flights possible between CDG, GLA, KEF BOS
# Multi-Connecting flights possible between CDG, GLA, EWR BOS
# Multi-Connecting flights possible between CDG, GLA, FCO BOS
# Multi-Connecting flights possible between CDG, GLA, YYZ BOS
# Multi-Connecting flights possible between CDG, KRK, DUB BOS
# Multi-Connecting flights possible between CDG, KRK, MAD BOS
# Multi-Connecting flights possible between CDG, KRK, SNN BOS
# Multi-Connecting flights possible between CDG, KRK, AMS BOS
# Multi-Connecting flights possible between CDG, KRK, ZRH BOS
# Multi-Connecting flights possible between CDG, KRK, FRA BOS
# Multi-Connecting flights possible between CDG, KRK, MUC BOS
# Multi-Connecting flights possible between CDG, LGW, LAS BOS
# Multi-Connecting flights possible between CDG, LGW, MCO BOS
# Multi-Connecting flights possible between CDG, LGW, TPA BOS
# Multi-Connecting flights possible between CDG, LGW, AMS BOS
# Multi-Connecting flights possible between CDG, LGW, BDA BOS
# Multi-Connecting flights possible between CDG, LGW, CUN BOS
# Multi-Connecting flights possible between CDG, LGW, FCO BOS
# Multi-Connecting flights possible between CDG, LGW, DUB BOS
# Multi-Connecting flights possible between CDG, LGW, DXB BOS
# Multi-Connecting flights possible between CDG, LGW, KEF BOS
# Multi-Connecting flights possible between CDG, LGW, SNN BOS
# Multi-Connecting flights possible between CDG, LGW, LIS BOS
# Multi-Connecting flights possible between CDG, LGW, PDL BOS
# Multi-Connecting flights possible between CDG, LGW, PUJ BOS
# Multi-Connecting flights possible between CDG, LGW, YUL BOS
# Multi-Connecting flights possible between CDG, LGW, YYZ BOS
# Multi-Connecting flights possible between CDG, LGW, MAD BOS
# Multi-Connecting flights possible between CDG, LGW, MUC BOS
# Multi-Connecting flights possible between CDG, LGW, ZRH BOS
# Multi-Connecting flights possible between CDG, LPL, DUB BOS
# Multi-Connecting flights possible between CDG, LPL, SNN BOS
# Multi-Connecting flights possible between CDG, LPL, AMS BOS
# Multi-Connecting flights possible between CDG, LPL, LIS BOS
# Multi-Connecting flights possible between CDG, LPL, MAD BOS
# Multi-Connecting flights possible between CDG, LTN, DUB BOS
# Multi-Connecting flights possible between CDG, LTN, AMS BOS
# Multi-Connecting flights possible between CDG, LTN, KEF BOS
# Multi-Connecting flights possible between CDG, LTN, LIS BOS
# Multi-Connecting flights possible between CDG, LTN, MAD BOS
# Multi-Connecting flights possible between CDG, LTN, ZRH BOS
# Multi-Connecting flights possible between CDG, LTN, FCO BOS
# Multi-Connecting flights possible between CDG, OPO, ZRH BOS
# Multi-Connecting flights possible between CDG, OPO, FCO BOS
# Multi-Connecting flights possible between CDG, OPO, LHR BOS
# Multi-Connecting flights possible between CDG, OPO, AMS BOS
# Multi-Connecting flights possible between CDG, OPO, DUB BOS
# Multi-Connecting flights possible between CDG, OPO, LIS BOS
# Multi-Connecting flights possible between CDG, OPO, MAD BOS
# Multi-Connecting flights possible between CDG, OPO, FRA BOS
# Multi-Connecting flights possible between CDG, OPO, MUC BOS
# Multi-Connecting flights possible between CDG, OPO, PDL BOS
# Multi-Connecting flights possible between CDG, OPO, YYZ BOS
# Multi-Connecting flights possible between CDG, OPO, EWR BOS
# Multi-Connecting flights possible between CDG, RAK, MAD BOS
# Multi-Connecting flights possible between CDG, RAK, MUC BOS
# Multi-Connecting flights possible between CDG, RAK, DUB BOS
# Multi-Connecting flights possible between CDG, RAK, AMS BOS
# Multi-Connecting flights possible between CDG, RAK, ZRH BOS
# Multi-Connecting flights possible between CDG, RAK, LIS BOS
# Multi-Connecting flights possible between CDG, TFS, MUC BOS
# Multi-Connecting flights possible between CDG, TFS, ZRH BOS
# Multi-Connecting flights possible between CDG, TFS, FRA BOS
# Multi-Connecting flights possible between CDG, TFS, DUB BOS
# Multi-Connecting flights possible between CDG, TFS, MAD BOS
# Multi-Connecting flights possible between CDG, TFS, SNN BOS
# Multi-Connecting flights possible between CDG, TFS, AMS BOS
# Multi-Connecting flights possible between CDG, TFS, FCO BOS
# Multi-Connecting flights possible between CDG, SVX, DXB BOS
# Multi-Connecting flights possible between CDG, SVX, FCO BOS
# Multi-Connecting flights possible between CDG, SVX, MUC BOS
# Multi-Connecting flights possible between CDG, CMB, FCO BOS
# Multi-Connecting flights possible between CDG, CMB, DXB BOS
# Multi-Connecting flights possible between CDG, CMB, FRA BOS
# Multi-Connecting flights possible between CDG, CMB, LHR BOS
# Multi-Connecting flights possible between CDG, CMB, NRT BOS
# Multi-Connecting flights possible between CDG, RAI, LIS BOS
# Multi-Connecting flights possible between CDG, VXE, LIS BOS
# Multi-Connecting flights possible between CDG, VXE, RAI BOS
# Multi-Connecting flights possible between CDG, MCT, DXB BOS
# Multi-Connecting flights possible between CDG, MCT, ZRH BOS
# Multi-Connecting flights possible between CDG, MCT, FRA BOS
# Multi-Connecting flights possible between CDG, MCT, LHR BOS
# Multi-Connecting flights possible between CDG, MCT, MUC BOS
# Multi-Connecting flights possible between CDG, TGD, FCO BOS
# Multi-Connecting flights possible between CDG, TGD, FRA BOS
# Multi-Connecting flights possible between CDG, TGD, ZRH BOS
# Multi-Connecting flights possible between CDG, FAO, MUC BOS
# Multi-Connecting flights possible between CDG, FAO, LHR BOS
# Multi-Connecting flights possible between CDG, FAO, DUB BOS
# Multi-Connecting flights possible between CDG, FAO, SNN BOS
# Multi-Connecting flights possible between CDG, FAO, LIS BOS
# Multi-Connecting flights possible between CDG, FAO, AMS BOS
# Multi-Connecting flights possible between CDG, FAO, FRA BOS
